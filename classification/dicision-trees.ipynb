# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics, preprocessing
import matplotlib.image as mpimg
import pydotplus 
from io import StringIO
from sklearn import tree

# %%
df = pd.read_csv('data/teleCust1000t.csv')

# %%
df.hist(bins=50)
# Out:
# array([[<Axes: title={'center': 'region'}>,
#         <Axes: title={'center': 'tenure'}>,
#         <Axes: title={'center': 'age'}>],
#        [<Axes: title={'center': 'marital'}>,
#         <Axes: title={'center': 'address'}>,
#         <Axes: title={'center': 'income'}>],
#        [<Axes: title={'center': 'ed'}>,
#         <Axes: title={'center': 'employ'}>,
#         <Axes: title={'center': 'retire'}>],
#        [<Axes: title={'center': 'gender'}>,
#         <Axes: title={'center': 'reside'}>,
#         <Axes: title={'center': 'custcat'}>]], dtype=object)

# %%
df.isnull().sum()
# Out:
# region     0
# tenure     0
# age        0
# marital    0
# address    0
# income     0
# ed         0
# employ     0
# retire     0
# gender     0
# reside     0
# custcat    0
# dtype: int64

# %%
df['custcat'].value_counts()
# Out:
# custcat
# 3    281
# 1    266
# 4    236
# 2    217
# Name: count, dtype: int64

# %%
x = df[['region', 'tenure', 'age', 'marital', 'address', 'income', 'ed', 'employ', 'retire', 'gender', 'reside']].values   
y = df['custcat'].values


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
model = DecisionTreeClassifier(criterion='entropy', max_depth=3)
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
metrics.accuracy_score(y_test, model.predict(x_test))
# Out:
# 0.395

# %%
# dot_data = StringIO()
# filename = "drugtree.png"
# featureNames = df.columns[0:11]
# out = tree.export_graphviz(model, feature_names=featureNames, out_file=dot_data, class_names=np.unique(y_train),filled=True, special_characters=True, rotate=True)
# graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# graph.write_png(filename)
# img = mpimg.imread(filename)
# plt.figure(figsize=(100, 200))
# plt.imshow(img, interpolation='nearest')
